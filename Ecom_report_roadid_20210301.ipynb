# %%
from sqlalchemy import create_engine
# %load_ext sql
import pandas as pd
import numpy as np
import datetime
from datetime import date, timedelta

# %%
# %sql clickhouse://liubov-shalimova:pswrd@clickhouse.cc.local:8123/default
# Out:
# 'Connected: liubov-shalimova@default'

# %% [markdown]
# ##### this file is for RoadID
# ###### coupon like '%nenlahapcbofgnanklpelkaejcehkggg%' is WikiByu, coupon like '%bmnlcjabgnpnenekpadlanbbkooimhnj%' is Honey

# %%
import ecom_queries
from ecom_queries import querryForStatsP0, querryForStatsP1, querryForStatsP2, querryforthankyoupage, querryforextentionblocked
organizationId = '17c4679b-dcec-4771-989e-5ee5305201b3' 
orgname_res = %sql select name from bo.organizations_mysql where orgId = :organizationId
orgname = orgname_res[0][0]
frames0 = []
frames1 = []
frames2 = []
framesth = []
framesexb = []
for i in range(1,14):
    start_date = date.today() - timedelta(days=i)
    end_date = date.today() - timedelta(days=i)
    start_date_str = start_date.strftime('%Y-%m-%d')
    end_date_str = end_date.strftime('%Y-%m-%d')
    #print(start_date_str)
    #print(start_date_str)
    statsP0 = %sql $querryForStatsP0
    statsP1 = %sql $querryForStatsP1
    statsP2 = %sql $querryForStatsP2
    thnkpage = %sql $querryforthankyoupage
    extensionblocked = %sql $querryforextentionblocked
    statsP0 = statsP0.DataFrame()
    frames0.append(statsP0)
    statsP1 = statsP1.DataFrame()
    frames1.append(statsP1)
    statsP2 = statsP2.DataFrame()
    frames2.append(statsP2)
    thnkpage = thnkpage.DataFrame()
    framesth.append(thnkpage)
    extensionblocked = extensionblocked.DataFrame()
    framesexb.append(extensionblocked)
    dates = start_date_str
    statsP0['idx_date']=dates
    statsP1['idx_date']=dates
    statsP2['idx_date']=dates
    thnkpage['idx_date']=dates
    extensionblocked['idx_date']=dates
statsP0 = pd.concat(frames0)
statsP1 = pd.concat(frames1)
statsP2 = pd.concat(frames2)
thnkpage = pd.concat(framesth)
extensionblocked = pd.concat(framesexb)
print(statsP0)
print(statsP1)
print(statsP2)
print(thnkpage)
print(extensionblocked)
# Out:
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#  * clickhouse://liubov-shalimova:***@clickhouse.clean.local:8123/default
# Done.
#   orders_with_blocking sales_with_blocking   estimated_savings  \
# 0                   87   2529.639981985092  1145.0400000000004
# 0                   45  1288.3599882125854  261.00000000000017
# 0                   29   988.7099952697754  104.25999999999998
# 0                   29   891.1699919700623   74.65000000000002
# 0                   30   863.7300033569336   63.17000000000002
# 0                   41  1420.1399984359741   83.99000000000001
# 0                   30   931.3800039291382   46.94000000000001
# 0                   28   970.8600082397461   65.20000000000003
# 0                   15   497.5399990081787   45.40000000000001
# 0                   18   696.4800000190735               43.99
# 0                   36  1275.3199863433838               74.87
# 0                   15  468.01000022888184               30.39
# 0                   23   815.6699924468994   78.29000000000002
#
#      applied_discount gross_revenue_with_coupons_blocked_applied  \
# 0  1326.5100000000004                         3856.1499819850924
# 0   641.5800000000003                         1929.9399882125858
# 0              166.87                         1155.5799952697753
# 0              134.84                         1026.0099919700622
# 0   89.39999999999999                          953.1300033569336
# 0              181.34                          1601.479998435974
# 0  158.59999999999997                          1089.980003929138
# 0              145.87                          1116.730008239746
# 0  115.10999999999999                          612.6499990081787
# 0  58.480000000000004                          754.9600000190735
# 0              104.38                          1379.699986343384
# 0   58.64000000000001                          526.6500002288818
# 0               54.96                          870.6299924468995
#
#   percentage_of_gross_sales_saved    idx_date
# 0              29.693865781915196  2021-02-28
# 0              13.523736571815654  2021-02-27
# 0               9.022309180392138  2021-02-26
# 0               7.275757603165547  2021-02-25
# 0               6.627637339871228  2021-02-24
# 0               5.244523820592559  2021-02-23
# 0              4.3065010211922825  2021-02-22
# 0              5.8384747896917375  2021-02-21
# 0                 7.4104301107481  2021-02-20
# 0               5.826798770648594  2021-02-19
# 0                5.42654205559774  2021-02-18
# 0               5.770435770776136  2021-02-17
# 0               8.992338959052688  2021-02-16
#    total_coupons_blocked  total_carts_with_blocking  \
# 0                    515                        119
# 0                    224                         58
# 0                    201                         43
# 0                    110                         41
# 0                    210                         40
# 0                    188                         53
# 0                    148                         42
# 0                    198                         35
# 0                    122                         20
# 0                    111                         27
# 0                    255                         45
# 0                    125                         22
# 0                    182                         31
#
#    total_unique_coupon_codes    idx_date
# 0                         36  2021-02-28
# 0                         22  2021-02-27
# 0                         25  2021-02-26
# 0                         22  2021-02-25
# 0                         39  2021-02-24
# 0                         34  2021-02-23
# 0                         71  2021-02-22
# 0                         50  2021-02-21
# 0                         23  2021-02-20
# 0                         22  2021-02-19
# 0                         28  2021-02-18
# 0                         18  2021-02-17
# 0                         22  2021-02-16
#    total_protected_pageviews    idx_date
# 0                      90333  2021-02-28
# 0                      72211  2021-02-27
# 0                      33971  2021-02-26
# 0                      33360  2021-02-25
# 0                      47769  2021-02-24
# 0                      44279  2021-02-23
# 0                      41357  2021-02-22
# 0                      47238  2021-02-21
# 0                      43924  2021-02-20
# 0                      43204  2021-02-19
# 0                      63130  2021-02-18
# 0                      27486  2021-02-17
# 0                      24663  2021-02-16
#    thankyoupage    idx_date
# 0          1458  2021-02-28
# 0          1048  2021-02-27
# 0           475  2021-02-26
# 0           458  2021-02-25
# 0           626  2021-02-24
# 0           644  2021-02-23
# 0           579  2021-02-22
# 0           591  2021-02-21
# 0           460  2021-02-20
# 0           546  2021-02-19
# 0           694  2021-02-18
# 0           342  2021-02-17
# 0           350  2021-02-16
#    extension_blocked    idx_date
# 0               4747  2021-02-28
# 0               2413  2021-02-27
# 0               1686  2021-02-26
# 0               1623  2021-02-25
# 0               2292  2021-02-24
# 0               2245  2021-02-23
# 0               1868  2021-02-22
# 0               1325  2021-02-21
# 0               1092  2021-02-20
# 0               1440  2021-02-19
# 0               2601  2021-02-18
# 0               1394  2021-02-17
# 0               1464  2021-02-16

# %%
#assigning needed type for collumns and seting idx_date as index
statsP0 = statsP0.drop(columns=['gross_revenue_with_coupons_blocked_applied', 'percentage_of_gross_sales_saved'])
statsP0['orders_with_blocking']=statsP0['orders_with_blocking'].astype('float64')
statsP0['estimated_savings']=statsP0['estimated_savings'].astype('float64')
statsP0['applied_discount']=statsP0['applied_discount'].astype('float64')
statsP0['sales_with_blocking']=statsP0['sales_with_blocking'].astype('float64')
statsP0['idx_date']=statsP0['idx_date'].astype('datetime64')
statsP0 = statsP0.set_index('idx_date')

statsP1['total_coupons_blocked']=statsP1['total_coupons_blocked'].astype('int64')
statsP1['total_carts_with_blocking']=statsP1['total_carts_with_blocking'].astype('int64')
statsP1['total_unique_coupon_codes']=statsP1['total_unique_coupon_codes'].astype('int64')
statsP1 = statsP1.rename(columns={"total_unique_coupon_codes": "total_unique_coupon"})
statsP1['idx_date']=statsP1['idx_date'].astype('datetime64')
statsP1 = statsP1.set_index('idx_date')

statsP2['total_protected_pageviews']=statsP2['total_protected_pageviews'].astype('int64')
statsP2['idx_date']=statsP2['idx_date'].astype('datetime64')
statsP2 = statsP2.set_index('idx_date')

thnkpage['thankyoupage']=thnkpage['thankyoupage'].astype('int64')
thnkpage['idx_date']=thnkpage['idx_date'].astype('datetime64')
thnkpage = thnkpage.set_index('idx_date')

extensionblocked['extension_blocked']=extensionblocked['extension_blocked'].astype('int64')
extensionblocked['idx_date']=extensionblocked['idx_date'].astype('datetime64')
extensionblocked = extensionblocked.set_index('idx_date')

# %%
#merging all dataframes nd rounding numbers
mergedStats_raw_raw = statsP0.merge(statsP1, on = 'idx_date').merge(statsP2, on = 'idx_date').merge(thnkpage, on = 'idx_date').merge(extensionblocked, on = 'idx_date')
mergedStats_raw=mergedStats_raw_raw.round(2)
mergedStats_raw
# Out:
#             orders_with_blocking  sales_with_blocking  estimated_savings  \
# idx_date
# 2021-02-28                  87.0              2529.64            1145.04
# 2021-02-27                  45.0              1288.36             261.00
# 2021-02-26                  29.0               988.71             104.26
# 2021-02-25                  29.0               891.17              74.65
# 2021-02-24                  30.0               863.73              63.17
# 2021-02-23                  41.0              1420.14              83.99
# 2021-02-22                  30.0               931.38              46.94
# 2021-02-21                  28.0               970.86              65.20
# 2021-02-20                  15.0               497.54              45.40
# 2021-02-19                  18.0               696.48              43.99
# 2021-02-18                  36.0              1275.32              74.87
# 2021-02-17                  15.0               468.01              30.39
# 2021-02-16                  23.0               815.67              78.29
#
#             applied_discount  total_coupons_blocked  \
# idx_date
# 2021-02-28           1326.51                    515
# 2021-02-27            641.58                    224
# 2021-02-26            166.87                    201
# 2021-02-25            134.84                    110
# 2021-02-24             89.40                    210
# 2021-02-23            181.34                    188
# 2021-02-22            158.60                    148
# 2021-02-21            145.87                    198
# 2021-02-20            115.11                    122
# 2021-02-19             58.48                    111
# 2021-02-18            104.38                    255
# 2021-02-17             58.64                    125
# 2021-02-16             54.96                    182
#
#             total_carts_with_blocking  total_unique_coupon  \
# idx_date
# 2021-02-28                        119                   36
# 2021-02-27                         58                   22
# 2021-02-26                         43                   25
# 2021-02-25                         41                   22
# 2021-02-24                         40                   39
# 2021-02-23                         53                   34
# 2021-02-22                         42                   71
# 2021-02-21                         35                   50
# 2021-02-20                         20                   23
# 2021-02-19                         27                   22
# 2021-02-18                         45                   28
# 2021-02-17                         22                   18
# 2021-02-16                         31                   22
#
#             total_protected_pageviews  thankyoupage  extension_blocked
# idx_date
# 2021-02-28                      90333          1458               4747
# 2021-02-27                      72211          1048               2413
# 2021-02-26                      33971           475               1686
# 2021-02-25                      33360           458               1623
# 2021-02-24                      47769           626               2292
# 2021-02-23                      44279           644               2245
# 2021-02-22                      41357           579               1868
# 2021-02-21                      47238           591               1325
# 2021-02-20                      43924           460               1092
# 2021-02-19                      43204           546               1440
# 2021-02-18                      63130           694               2601
# 2021-02-17                      27486           342               1394
# 2021-02-16                      24663           350               1464

# %%
#mergedStats_raw.to_csv('roadis_honey_2weeks.csv')

# %%
#handling missing data in the past 30 days
if mergedStats_raw.index.all != date.today() - timedelta(days=1):
    mergedStats = mergedStats_raw.dropna(axis='rows')
else:
    print('corrupted data in yesterday')
mergedStats

# %%
median_data=mergedStats.median().round(2)
median_data

# %%
#import pandas_profiling
#mergedStats.profile_report()

# %%
yesterday = date.today() - timedelta(days=1)
two_days_ago = date.today() - timedelta(days=2)
yesterday_str = yesterday.strftime('%Y-%m-%d')
two_days_ago_str = two_days_ago.strftime('%Y-%m-%d')
week_ago = date.today() - timedelta(days=8)
week_ago_str = week_ago.strftime('%Y-%m-%d')

# %%
latest_stats = mergedStats.loc[mergedStats.index == yesterday_str]
latest_stats

# %%
two_days_ago_stats = mergedStats.loc[mergedStats.index == two_days_ago_str]
two_days_ago_stats

# %%
week_ago_stats = mergedStats.loc[mergedStats.index == week_ago_str]
week_ago_stats

# %%
diff_between_days_raw = (mergedStats.loc[mergedStats.index == yesterday_str].values/mergedStats.loc[mergedStats.index == two_days_ago_str].values)*100 - 100
diff_between_days=diff_between_days_raw.round(2)
diff_between_days = pd.DataFrame(diff_between_days, columns=mergedStats.columns)
print('% diff between', yesterday_str, 'and', two_days_ago_str)
diff_between_days

# %%
diff_between_days_of_week_raw = (mergedStats.loc[mergedStats.index == yesterday_str].values/mergedStats.loc[mergedStats.index == week_ago_str].values)*100 - 100
diff_between_days_of_week=diff_between_days_of_week_raw.round(2)
diff_between_days_of_week = pd.DataFrame(diff_between_days_of_week, columns=mergedStats.columns)
print('% diff between', yesterday_str, 'and', week_ago_str)
diff_between_days_of_week

# %%
es = mergedStats._get_value(yesterday_str, 'estimated_savings')
ad = mergedStats._get_value(yesterday_str, 'applied_discount')
ob = mergedStats._get_value(yesterday_str, 'orders_with_blocking')
sb = mergedStats._get_value(yesterday_str, 'sales_with_blocking')
tcoupb = mergedStats._get_value(yesterday_str, 'total_coupons_blocked')
tcartb = mergedStats._get_value(yesterday_str, 'total_carts_with_blocking')
tpv = mergedStats._get_value(yesterday_str, 'total_protected_pageviews')
thp = mergedStats._get_value(yesterday_str, 'thankyoupage')
extblockd = mergedStats._get_value(yesterday_str, 'extension_blocked')

# %%
class formating_text:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
def deviation_es(var):
    var = abs(100-var/median_data.get('estimated_savings')*100)
    return var
def deviation_ob(var):
    var = abs(100-var/median_data.get('orders_with_blocking')*100)
    return var
def deviation_ad(var):
    var = abs(100-var/median_data.get('applied_discount')*100)
    return var
def deviation_sb(var):
    var = abs(100-var/median_data.get('sales_with_blocking')*100)
    return var
def deviation_tcoupb(var):
    var = abs(100-var/median_data.get('total_coupons_blocked')*100)
    return var
def deviation_tcartb(var):
    var = abs(100-var/median_data.get('total_carts_with_blocking')*100)
    return var
def deviation_tpv(var):
    var = abs(100-var/median_data.get('total_protected_pageviews')*100)
    return var
def deviation_thp(var):
    var = abs(100-var/median_data.get('thankyoupage')*100)
    return var
def deviation_exb(var):
    var = abs(100-var/median_data.get('extension_blocked')*100)
    return var
es_deviation=deviation_es(es)
ob_deviation=deviation_ob(ob)
ad_deviation=deviation_ad(ad)
sb_deviation=deviation_sb(sb)
tcoupb_deviation=deviation_tcoupb(tcoupb)
tcartb_deviation=deviation_tcartb(tcartb)
tpv_deviation = deviation_tpv(tpv)
thp_deviation = deviation_thp(thp)
extblockd_deviation = deviation_exb(extblockd)
validation_list = {'estimated_savings_deviation': float(es_deviation[0]), 
                   'orders_with_blocking_deviation': float(ob_deviation[0]), 'applied_discount': float(ad_deviation[0]), 'sales_with_blocking_deviation': float(sb_deviation[0]), 
                   'total_coupons_blocked': float(tcoupb_deviation[0]), 'total_carts_with_blocking_deviation': float(tcartb_deviation[0]), 
                   'total_protected_pageviews_deviation': float(tpv_deviation[0]), 'thankyoupage_deviation':float(thp_deviation[0]), 
                   'extentions_blocked_deviation':float(extblockd_deviation[0])}
print(validation_list)
for keys, values in validation_list.items():
    if values > 50:
        print(formating_text.BOLD, keys, formating_text.END, 'data for',yesterday_str, formating_text.BOLD, 'contains anomaly', formating_text.END)
    else:
        print(formating_text.BOLD, keys, formating_text.END, 'data for',yesterday_str, formating_text.BOLD, 'is good:', formating_text.END,  'no deviation more than 50% from median')

# %%
framesc=[]
for i in range(1, 14):
    start_date = date.today() - timedelta(days=i)
    end_date = date.today() - timedelta(days=i)
    start_date_str = start_date.strftime('%Y-%m-%d')
    end_date_str = end_date.strftime('%Y-%m-%d')
    coupon_stats = %sql SELECT upper(trimBoth(events.couponCode)) AS coupon, COUNT(*) AS total_coupons_blocked FROM ecomm_all_events events WHERE clientEvent = 1 AND eventName = 3 AND trimBoth(events.couponCode) != '' AND uuidPath is not null AND (events.coupon like '%nenlahapcbofgnanklpelkaejcehkggg%'  or events.coupon like '%bmnlcjabgnpnenekpadlanbbkooimhnj%') AND idx_date >= :start_date_str AND idx_date <= :end_date_str AND publisherHostname = 'www.roadid.com' AND trimBoth(orderCurrencySymbol) = '$' GROUP BY coupon ORDER BY total_coupons_blocked DESC LIMIT 5
    coupon_stats = coupon_stats.DataFrame()
    framesc.append(coupon_stats)
    dates = start_date_str    
    coupon_stats['idx_date']=dates
coupon_stats = pd.concat(framesc)   
coupon_stats['coupon']=coupon_stats['coupon'].astype('category')
coupon_stats['total_coupons_blocked']=coupon_stats['total_coupons_blocked'].astype('int64')
coupon_stats['idx_date']=coupon_stats['idx_date'].astype('datetime64')
coupon_stats_raw = coupon_stats.set_index('idx_date')

# %%
#mergedStats_raw.to_csv('roadis_honey_2weeks.csv')

# %%
coupon_stats1 = coupon_stats_raw.pivot(columns = 'coupon')
coupon_stats=coupon_stats1.replace(np.nan, '-')
tocsv = coupon_stats.sort_values('idx_date', ascending=False)
tocsv

# %%
tocsv.to_csv('roadid_honey_coupons_2weeks.csv')

# %%
query_for_version_stats = """select count(version) cv, version, idx_date from ecomm_all_events where publisherHostname = 'www.roadid.com'
                            and idx_date > :week_ago_str group by idx_date, version
                            having cv > 10
                            order by idx_date desc"""
versionStats = %sql $query_for_version_stats
versionStats = versionStats.DataFrame()
versionStats = versionStats.rename(columns={"cv": "events_count"})
versionStats = versionStats.set_index('idx_date')
versionStats

# %% [markdown]
# ### Report ends here, below are draft cells

# %%
q1 = """select count(*) from 
feed_appnexus where last_seen > '2021-02-23 15:00:00'"""
newstatsPo = %sql $q1
newstatsPo=newstatsPo.DataFrame()
newstatsPo
newstatsPo = newstatsPo.rename(columns={"count()": "Count v"})
newstatsPo

# %%
framesexttotal = []
framesexhoney = []
framesexwiki = []
for i in range(1,14):
    start_date = date.today() - timedelta(days=i)
    end_date = date.today() - timedelta(days=i)
    start_date_str = start_date.strftime('%Y-%m-%d')
    end_date_str = end_date.strftime('%Y-%m-%d')
    qext_total = """SELECT count(*) as extension_blocked FROM ecomm_all_events
    WHERE publisherHostname in ('roadid.com', 'www.roadid.com') and (extension like '%nenlahapcbofgnanklpelkaejcehkggg%' or extension like '%bmnlcjabgnpnenekpadlanbbkooimhnj%')
      AND idx_date >= :start_date_str AND idx_date <= :end_date_str and extensionState = 1"""
    qext_honey = """SELECT count(*) as extension_blocked FROM ecomm_all_events
    WHERE publisherHostname in ('roadid.com', 'www.roadid.com') and (extension like '%bmnlcjabgnpnenekpadlanbbkooimhnj%')
      AND idx_date >= :start_date_str AND idx_date <= :end_date_str and extensionState = 1"""
    qext_wiki = """SELECT count(*) as extension_blocked FROM ecomm_all_events
    WHERE publisherHostname in ('roadid.com', 'www.roadid.com') and (extension like '%nenlahapcbofgnanklpelkaejcehkggg%')
      AND idx_date >= :start_date_str AND idx_date <= :end_date_str and extensionState = 1"""
    extenblock_total= %sql $qext_total
    extenblock_total = extenblock_total.DataFrame()
    extblock_honey= %sql $qext_honey
    extblock_honey = extblock_honey.DataFrame()
    extblock_wiki = %sql $qext_wiki
    extblock_wiki = extblock_wiki.DataFrame()
    framesexttotal.append(extenblock_total)
    framesexhoney.append(extblock_honey)
    framesexwiki.append(extblock_wiki)
    dates = start_date_str
    extenblock_total['idx_date']=dates
    extblock_honey['idx_date']=dates
    extblock_wiki['idx_date']=dates
extenblock_total = pd.concat(framesexttotal)
extblock_honey = pd.concat(framesexhoney)
extblock_wiki = pd.concat(framesexwiki)
print(extenblock_total)
print(extblock_wiki)
print(extblock_honey)

# %%
extblock_honey.to_csv('roadid_extension_blocked_honey.csv')
